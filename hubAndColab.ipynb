# %% [markdown]
# <a href="https://colab.research.google.com/github/Leandro-Bezerra-de-Carvalho/base-alunos-GENERATION-/blob/main/hubAndColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone COLAR A URL

# !git clone https://github.com/Leandro-Bezerra-de-Carvalho/base-alunos-GENERATION-
# Out:
# Cloning into 'base-alunos-GENERATION-'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# Contar quantos alunos tem

import pandas as pd
# Onde esta o arquivo
dataBase = '/content/base-alunos-GENERATION-/github - Página1.csv'
# python ler o arquivo

# contar e mostrar as informações
# with open(arquivo, metodo)
# métodos: 'r'read(Leitura)| 'a'append(Colocar infos) | 'w'write(Deletar tudo e colocar denovo)
with open(dataBase, 'r') as arquivo:
  qtd_lines = arquivo.readlines()

print(len(qtd_lines))
# Out:
# 53
